# %%
# #File Handling
# file=open("aws1.txt")
# print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 #File Handling
# ----> 2 file=open("aws1.txt")
#       3 print(file.read())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'aws1.txt'

# %%
with open('aws.txt') as f:
    print(f.read())
# Out:
# onprime cluster
#
#
# AWS -> Amazon Web Services -> 2006-> largest cloud provider->200+services
#
# web services->
#
# when to use asw?
# host websites->s3,es2
# store->s3
# run backend appliction->api gateway
# mobile applications-> amplifiers
#
#
# 1)IAM ->Identity and access management
# a)Manage Users
# b)User Groups
# c)policies
# d)permissions
#
# authenticate->who you are
#  and authorize -> what you are allowed to
#
# why IAM ?
# Advantages :
# security by role
# fine access control
#
# IAM core Concepts->
# users-> individual person
# groups
# policies
#
#
# EC2-> Elastic Compute Cloud
# instance-> launch servers within minutes
# choose any os,storage,cpu,memory
#
# RSA
# ED2519
#
# ssh->sECURE SHELL
#
# cd downloads
# chmod 400 yourkey pair.pem
# ssh -i your keypair.pem ec2-user@<ip address>
#
# s3-> simple , storage , service
# buckets -> folders -> no limits
# file -> object -> no limit
# hosting static web sites
# store backups
# upload the profile pictures
# ...

# %%
# read single line from readline()
file=open('aws.txt','r')
print(file.readline())
# Out:
# onprime cluster

# %%
# read single character from file :
with open('aws.txt')as f:
    print(f.read(5))
# Out:
# onpri

# %%
# iterator method
with open('aws.txt') as f:
    for i in f:
        print(i)
# Out:
# onprime cluster
#
#
#
#
#
# AWS -> Amazon Web Services -> 2006-> largest cloud provider->200+services
#
#
#
# web services->
#
#
#
# when to use asw?
#
# host websites->s3,es2
#
# store->s3
#
# run backend appliction->api gateway
#
# mobile applications-> amplifiers
#
#
#
#
#
# 1)IAM ->Identity and access management
#
# a)Manage Users
#
# b)User Groups
#
# c)policies
#
# d)permissions
#
#
#
# authenticate->who you are
#
#  and authorize -> what you are allowed to
#
#
#
# why IAM ?
#
# Advantages :
#
# security by role
#
# fine access control
#
#
#
# IAM core Concepts->
#
# users-> individual person
#
# groups
#
# policies
#
#
#
#
#
# EC2-> Elastic Compute Cloud
#
# instance-> launch servers within minutes
#
# choose any os,storage,cpu,memory
#
#
#
# RSA
#
# ED2519
#
#
#
# ssh->sECURE SHELL
#
#
#
# cd downloads
#
# chmod 400 yourkey pair.pem
#
# ssh -i your keypair.pem ec2-user@<ip address>
#
#
#
# s3-> simple , storage , service
#
# buckets -> folders -> no limits
#
# ...

# %%
# Create a file 
file=open("textfile.txt",'x')

# %%
file=open("newfile.txt",'w')
file.write("Hello How Are You")
# Out:
# 17

# %%
# for deleting file we have to use os module
import os
os.remove("aws.txt")
file=open("aws.txt")
print(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 4
#       2 import os
#       3 os.remove("aws.txt")
# ----> 4 file=open("aws.txt")
#       5 print(file)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'aws.txt'

# %%
try:
    print(x)
    print("Hello")
except:
    print("Handle")
else:
    print("else block")
finally:
    print("finally statement")
# Out:
# Handle
# finally statement

# %%
import time
import datetime
import os

try:
    while True:
        now = datetime.datetime.now()
        time_string = now.strftime("%H:%M:%S")
        date_string = now.strftime("%A, %d %B %Y")

        os.system('cls' if os.name == 'nt' else 'clear')  # Clear screen for each update
        print("🕒 Digital Clock\n")
        print("Time:", time_string)
        print("Date:", date_string)

        time.sleep(1)  # Update every 1 second
except KeyboardInterrupt:
    print("\nClock stopped.")
# Out:
# 🕒 Digital Clock
#
# Time: 19:52:00
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:01
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:02
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:03
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:05
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:07
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:08
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:09
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:10
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:11
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:12
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:13
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:14
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:15
# Date: Friday, 25 July 2025
# 🕒 Digital Clock
#
# Time: 19:52:16
# Date: Friday, 25 July 2025
#
# ...
